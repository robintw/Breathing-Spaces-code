# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
from get_aq_data import get_flo_data, ID_to_name

# %%
data, hourly_mean, daily_mean = get_flo_data()

# %%
daily_mean.index.min()
# Out:
# Timestamp('2019-03-07 00:00:00')

# %%
daily_mean.mean(axis=1).plot(figsize=(10,6))
#plt.grid(axis='both', which='minor')
plt.grid(axis='both', which='major')
plt.xlabel('Time')
plt.ylabel(r'$\mathrm{PM}_{2.5}$ ($\mu g / m^3$)')
plt.title('7th Mar-23rd Aug 2019', loc='right', fontstyle='italic')
plt.title('Daily average $\mathrm{PM}_{2.5}$, averaged across all sites')
plt.tight_layout()
plt.savefig('graphs/AllSiteMean.png', dpi=300)
