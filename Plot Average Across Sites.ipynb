# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
from get_aq_data import get_flo_data_new, ID_to_name

# %%
data, hourly_mean, daily_mean = get_flo_data_new()

# %%
daily_mean.index.min(), daily_mean.index.max()
# Out:
# (Timestamp('2019-02-27 00:00:00'), Timestamp('2020-06-29 00:00:00'))

# %%
daily_mean['2019-06-01':'2020-06-30'].mean(axis=1).plot(figsize=(10,6))
plt.grid(axis='both', which='major')
plt.xlabel('Time')
plt.ylabel(r'$\mathrm{PM}_{2.5}$ ($\mu g / m^3$)')
plt.title('30th June 2019-30th June 2020', loc='right', fontstyle='italic')
plt.title('Daily average $\mathrm{PM}_{2.5}$, averaged across all sites')
plt.tight_layout()
plt.savefig('graphs2020/AllSiteMean_OneYear.png', dpi=300)
