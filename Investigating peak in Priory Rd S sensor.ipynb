# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from get_aq_data import get_flo_data, ID_to_name

# %%
data, hourly_mean, daily_mean = get_flo_data()

# %%
ID_to_name
# Out:
# {'nesta-1': 'Priory Rd (South)',
#  'nesta-2': 'Priory Rd (North)',
#  'nesta-2-1': 'Priory Rd (North)',
#  'nesta-4': 'Horseshoe Bridge',
#  'nesta-5': 'Kent Rd',
#  'nesta-6': 'Portswood Rd',
#  'nesta-7': 'St Denys Rd',
#  'nesta-8': 'Priory Rd-Kent Rd junction'}

# %%
hourly_mean['2019-06-07']['nesta-1']
# Out:
# timestamp
# 2019-06-07 00:00:00     13.076667
# 2019-06-07 01:00:00     66.591944
# 2019-06-07 02:00:00    310.251111
# 2019-06-07 03:00:00    329.891111
# 2019-06-07 04:00:00    310.373889
# 2019-06-07 05:00:00    295.327500
# 2019-06-07 06:00:00    604.737778
# 2019-06-07 07:00:00    421.723056
# 2019-06-07 08:00:00     33.345556
# 2019-06-07 09:00:00      5.989444
# 2019-06-07 10:00:00      5.335278
# 2019-06-07 11:00:00      4.685000
# 2019-06-07 12:00:00      3.214722
# 2019-06-07 13:00:00      2.630278
# 2019-06-07 14:00:00      2.199444
# 2019-06-07 15:00:00      2.463056
# 2019-06-07 16:00:00      2.284722
# 2019-06-07 17:00:00      2.156111
# 2019-06-07 18:00:00      2.066667
# 2019-06-07 19:00:00      2.732500
# 2019-06-07 20:00:00      2.840278
# 2019-06-07 21:00:00      2.972778
# 2019-06-07 22:00:00      2.643333
# 2019-06-07 23:00:00      2.270833
# Freq: H, Name: nesta-1, dtype: float64

# %%
data.loc['2019-06-07','nesta-1'] = np.nan

# %%
daily_mean = data.resample('1D').mean()

# %%
daily_mean.rename(columns=ID_to_name).plot(figsize=(10, 6))
#plt.grid(axis='both', which='minor')
plt.grid(axis='both', which='major')
plt.xlabel('Time')
plt.ylabel(r'$\mathrm{PM}_{2.5}$ ($\mu g / m^3$)')
#plt.annotate("April", xy=(70, 35), xycoords='figure points')
plt.title('$\mathrm{PM}_{2.5}$ in St Denys')
plt.savefig('graphs/AllSites_WholePeriod.png', dpi=300)
