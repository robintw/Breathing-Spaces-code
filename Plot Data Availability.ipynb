# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
from get_aq_data import get_flo_data, ID_to_name

# %%
import missingno as msno

# %%
data, hourly_mean, daily_mean = get_flo_data()

# %%
dm2 = daily_mean.set_index(daily_mean.index.to_period())

# %%
dm2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 170 entries, 2019-03-07 to 2019-08-23
# Freq: D
# Data columns (total 7 columns):
# nesta-1    122 non-null float64
# nesta-2    133 non-null float64
# nesta-4    170 non-null float64
# nesta-5    141 non-null float64
# nesta-6    133 non-null float64
# nesta-7    133 non-null float64
# nesta-8    28 non-null float64
# dtypes: float64(7)
# memory usage: 10.6 KB

# %%
msno.matrix(dm2.rename(columns=ID_to_name), freq='W', sparkline=False)
plt.grid(axis='y')
plt.tight_layout()
plt.suptitle('Data Availability', fontsize=18)
plt.savefig('graphs/DataAvailability.png', dpi=200)
