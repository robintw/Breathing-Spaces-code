# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
from get_aq_data import get_flo_data, ID_to_name, TICKS_TWO_HOURLY

# %%
data, hourly_mean, daily_mean = get_flo_data()

# %% [markdown]
# ### Doing the error bars across time for the 15min averaging

# %%
all_sites = data.mean(axis=1)

# %%
avg_15min = all_sites['2019-04-15':'2019-05-30'].groupby(all_sites['2019-04-15':'2019-05-30'].index.time).median()
std_15min = all_sites['2019-04-15':'2019-05-30'].groupby(all_sites['2019-04-15':'2019-05-30'].index.time).std()

# %%
avg_15min.plot(figsize=(10, 6))
plt.fill_between(avg_15min.index, avg_15min - std_15min, avg_15min + std_15min, alpha=0.3)

plt.grid(axis='both', which='major')
plt.xlabel('Time')
plt.ylabel(r'$\mathrm{PM}_{2.5}$ ($\mu g / m^3$)')
plt.xticks(TICKS_TWO_HOURLY)
#plt.annotate("April", xy=(70, 35), xycoords='figure points')
plt.title('15 minute median $\mathrm{PM}_{2.5}$ in St Denys, mid-April to end of May, averaged across all sensors')
plt.tight_layout()
plt.savefig('graphs/15min_median_across_all_sensors.png', dpi=300)

# %%
avg_15min.plot(figsize=(10,6))
#plt.grid(axis='both', which='minor')
plt.grid(axis='both', which='major')
plt.xlabel('Time')
plt.ylabel(r'$\mathrm{PM}_{2.5}$ ($\mu g / m^3$)')
plt.xticks(TICKS_TWO_HOURLY)
#plt.annotate("April", xy=(70, 35), xycoords='figure points')
plt.title('15 minute median $\mathrm{PM}_{2.5}$ in St Denys, mid-April to end of May')
plt.tight_layout()
plt.savefig('graphs/15min_median.png', dpi=300)
