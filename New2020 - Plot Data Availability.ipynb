# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
from get_aq_data import get_flo_data_new, ID_to_name

# %%
import missingno as msno

# %%
data, hourly_mean, daily_mean = get_flo_data_new()

# %%
data.index.min(), data.index.max()
# Out:
# (Timestamp('2019-02-27 14:15:00'), Timestamp('2020-06-29 04:45:00'))

# %%
dm2 = daily_mean.set_index(daily_mean.index.to_period())

# %%
dm2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 489 entries, 2019-02-27 to 2020-06-29
# Freq: D
# Data columns (total 11 columns):
# nesta-1     432 non-null float64
# nesta-11    231 non-null float64
# nesta-12    225 non-null float64
# nesta-14    142 non-null float64
# nesta-2     228 non-null float64
# nesta-4     334 non-null float64
# nesta-5     419 non-null float64
# nesta-6     474 non-null float64
# nesta-7     449 non-null float64
# nesta-8     373 non-null float64
# nesta-9     149 non-null float64
# dtypes: float64(11)
# memory usage: 45.8 KB

# %%
msno.matrix(dm2.rename(columns=ID_to_name), freq='W', sparkline=False)
plt.grid(axis='y')
plt.tight_layout()
plt.suptitle('Data Availability', fontsize=18)
plt.savefig('graphs2020/DataAvailability.png', dpi=200)
